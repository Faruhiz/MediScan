# %%
import socket
import json

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
sock.connect(("localhost", 5001))

def send_command(cmd: dict):
    sock.sendall((json.dumps(cmd) + "\n").encode("utf-8"))
    data = sock.recv(8192).decode("utf-8")
    return json.loads(data)

# %%
# ✅ Deploy
print(send_command({
    "command": "deploy",
    "project_id": "project_001",
    "model_name": "segment"
}))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # ✅ Deploy
# ----> 2 print(send_command({
#       3     "command": "deploy",
#       4     "project_id": "project_001",
#       5     "model_name": "segment"
#       6 }))
#
# Cell In[7], line 9, in send_command(cmd)
#       7 def send_command(cmd: dict):
#       8     sock.sendall((json.dumps(cmd) + "\n").encode("utf-8"))
# ----> 9     data = sock.recv(8192).decode("utf-8")
#      10     return json.loads(data)
#
# KeyboardInterrupt:

# %%
# ✅ Predict
print(send_command({
    "command": "predict",
    "project_id": "project_001",
    "image_path": "image_001"
}))
# Out:
# {'status': 'success', 'data': {'status': 'success', 'message': 'Detection completed.', 'predict_result': 'non-cancer', 'confidence_scores': {'non-cancer': [0.44793301820755005, 0.4336443841457367, 0.35822248458862305]}, 'bounding_boxes': [{'class': 'non-cancer', 'confidence': 0.44793301820755005, 'box': {'x1': 0.0, 'y1': 0.15793228149414062, 'x2': 42.42255401611328, 'y2': 62.55610275268555}}, {'class': 'non-cancer', 'confidence': 0.4336443841457367, 'box': {'x1': 559.974609375, 'y1': 448.964111328125, 'x2': 639.613525390625, 'y2': 640.0}}, {'class': 'non-cancer', 'confidence': 0.35822248458862305, 'box': {'x1': 567.9318237304688, 'y1': 1.0518798828125, 'x2': 639.3189086914062, 'y2': 126.65225219726562}}]}}

# %%
# json cmd
response = send_command(
    {
    "command": "train",
    "project_id": "project_001",
    "model_name": "test_o_cls",
    "mode": "classify",
    }
)

# %%
# evaluate
print(send_command({
    "command": "evaluate",
    "project_id": "project_001",
    "model_name": "segment",
    "mode": "segment",
}))
# Out:
# {'status': 'success', 'data': {'message': 'YOLO test evaluation completed successfully', 'metrics': {'mAP50': 0.995, 'mAP50-95': 0.8385124999999999, 'overall_precision': 1.0, 'overall_recall': 1.0, 'overall_f1_score': 1.0, 'overall_accuracy': 1.0, 'class_details': {'cancer': {'precision': 1.0, 'recall': 1.0, 'f1_score': 1.0, 'accuracy': 1.0}, 'non-cancer': {'precision': 1.0, 'recall': 1.0, 'f1_score': 1.0, 'accuracy': 1.0}}}}}

# %%
sock.close()
